# %%
import numpy as np
import pandas as pd
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from io import BytesIO
import cv2
import urllib3
import wget
from google.cloud import bigquery
import shutil
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
sys.path.append('/home/tianlongxu/Image_Type_Classifier_Proj/')
sys.path.append('/home/tianlongxu/cropping-images/models/research')
sys.path.append('/home/tianlongxu/cropping-images/models/research/slim')
sys.path.append('/home/tianlongxu/cropping-images/models/research/object_detection/')
sys.path.append('/usr/local/python3')

# %%
from Model_Mart_Scripts.utility_functions import download_image
from Model_Mart_Scripts.utility_functions import create_dir_if_needed
from py_scripts.image_cropping_utility_functions import *
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline

# %%
from object_detection.utils.label_map_util import load_labelmap
from object_detection.utils.label_map_util import convert_label_map_to_categories
from object_detection.utils.label_map_util import create_category_index
from object_detection.utils import visualization_utils as vis_util

# %%
prefix = './'

# What model to download.
#MODEL_NAME = 'bathroomdata'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = prefix+ 'alex-models' + '/kitchen_inference_graph.pb'
# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join(prefix + 'alex-models', 'kitchen-detection.pbtxt')



model_dict = {
    "bathroom":{"PATH_TO_CKPT" : prefix+ 'alex-models' + '/bathroom_inference_graph.pb',
               "PATH_TO_LABELS" : os.path.join(prefix + 'alex-models', 'bathroom-detection.pbtxt'),
               "NUM_CLASSES" : 9},
    "diningroom":{"PATH_TO_CKPT" : prefix+ 'alex-models' + '/diningroom_inference_graph.pb',
               "PATH_TO_LABELS" : os.path.join(prefix + 'alex-models', 'diningroom-detection.pbtxt'),
                 "NUM_CLASSES" : 8},
    "kitchen":{"PATH_TO_CKPT" : prefix+ 'alex-models' + '/kitchen_inference_graph.pb',
               "PATH_TO_LABELS" : os.path.join(prefix + 'alex-models', 'kitchen-detection.pbtxt'),
              "NUM_CLASSES" : 11},
    "outdoor":{"PATH_TO_CKPT" : prefix+ 'alex-models' + '/outdoor_inference_graph.pb',
               "PATH_TO_LABELS" : os.path.join(prefix + 'alex-models', 'outdoor-detection.pbtxt'),
              "NUM_CLASSES" : 12},
    "livingroom":{"PATH_TO_CKPT" : prefix+ 'alex-models' + '/livingroom_inference_graph.pb',
               "PATH_TO_LABELS" : os.path.join(prefix + 'alex-models', 'livingroom-detection.pbtxt'),
                 "NUM_CLASSES" : 11},
    "bedroom":{"PATH_TO_CKPT" : prefix+ 'alex-models' + '/bedroom_inference_graph.pb',
               "PATH_TO_LABELS" : os.path.join(prefix + 'alex-models', 'bedroom-detection.pbtxt'),
              "NUM_CLASSES" : 11}
}

# %%
model_dict
# Out:
# {'bathroom': {'PATH_TO_CKPT': './alex-models/bathroom_inference_graph.pb',
#   'PATH_TO_LABELS': './alex-models/bathroom-detection.pbtxt',
#   'NUM_CLASSES': 9},
#  'diningroom': {'PATH_TO_CKPT': './alex-models/diningroom_inference_graph.pb',
#   'PATH_TO_LABELS': './alex-models/diningroom-detection.pbtxt',
#   'NUM_CLASSES': 8},
#  'kitchen': {'PATH_TO_CKPT': './alex-models/kitchen_inference_graph.pb',
#   'PATH_TO_LABELS': './alex-models/kitchen-detection.pbtxt',
#   'NUM_CLASSES': 11},
#  'outdoor': {'PATH_TO_CKPT': './alex-models/outdoor_inference_graph.pb',
#   'PATH_TO_LABELS': './alex-models/outdoor-detection.pbtxt',
#   'NUM_CLASSES': 12},
#  'livingroom': {'PATH_TO_CKPT': './alex-models/livingroom_inference_graph.pb',
#   'PATH_TO_LABELS': './alex-models/livingroom-detection.pbtxt',
#   'NUM_CLASSES': 11},
#  'bedroom': {'PATH_TO_CKPT': './alex-models/bedroom_inference_graph.pb',
#   'PATH_TO_LABELS': './alex-models/bedroom-detection.pbtxt',
#   'NUM_CLASSES': 11}}

# %%
model_dict['kitchen']
# Out:
# {'PATH_TO_CKPT': './alex-models/kitchen_inference_graph.pb',
#  'PATH_TO_LABELS': './alex-models/kitchen-detection.pbtxt',
#  'NUM_CLASSES': 11}

# %%
for k, v in model_dict.items():
    PATH_TO_CKPT = v['PATH_TO_CKPT']
    PATH_TO_LABELS = v['PATH_TO_LABELS']
    NUM_CLASSES = v["NUM_CLASSES"]
    detection_graph = tf.Graph()
    with detection_graph.as_default():
        od_graph_def = tf.GraphDef()
        with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
            serialized_graph = fid.read()
            od_graph_def.ParseFromString(serialized_graph)
            tf.import_graph_def(od_graph_def, name='')
    label_map = load_labelmap(PATH_TO_LABELS)
    categories = convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
    category_index = create_category_index(categories)
    model_dict[k]['detection_graph'] = detection_graph
    model_dict[k]['categories'] = categories
    model_dict[k]['category_index'] = category_index

# %%
inverse_model_dict = {}
for m, v in model_dict.items():
    print(m, v['categories'])
    for pair in v['categories']:
        print(pair['name'])
        inverse_model_dict[pair['name']] = m
# Out:
# bathroom [{'id': 1, 'name': 'Bath Rugs and Mats'}, {'id': 2, 'name': 'Centerset Bathroom Sink Faucets'}, {'id': 3, 'name': 'Sconces'}, {'id': 4, 'name': 'Showerheads'}, {'id': 5, 'name': 'Single Handle Bathroom Sink Faucets'}, {'id': 6, 'name': 'Toilet Bowls'}, {'id': 7, 'name': 'Vanities with Tops'}, {'id': 8, 'name': 'Vanity Mirrors'}, {'id': 9, 'name': 'Widespread Bathroom Sink Faucets'}]
# Bath Rugs and Mats
# Centerset Bathroom Sink Faucets
# Sconces
# Showerheads
# Single Handle Bathroom Sink Faucets
# Toilet Bowls
# Vanities with Tops
# Vanity Mirrors
# Widespread Bathroom Sink Faucets
# diningroom [{'id': 1, 'name': 'Accent Chairs'}, {'id': 2, 'name': 'Bookcases'}, {'id': 3, 'name': 'Chandeliers'}, {'id': 4, 'name': 'Dining Chairs'}, {'id': 5, 'name': 'Kitchen and Dining Tables'}, {'id': 6, 'name': 'Pendant Lights'}, {'id': 7, 'name': 'Sideboards and Buffets'}, {'id': 8, 'name': 'Vases'}]
# Accent Chairs
# Bookcases
# Chandeliers
# Dining Chairs
# Kitchen and Dining Tables
# Pendant Lights
# Sideboards and Buffets
# Vases
# kitchen [{'id': 1, 'name': 'Bar Stools'}, {'id': 2, 'name': 'Built-in Dishwasher'}, {'id': 3, 'name': 'Electric Or Gas Range'}, {'id': 4, 'name': 'French Door Refrigerator'}, {'id': 5, 'name': 'Knife Set'}, {'id': 6, 'name': 'Over the Range Microwave'}, {'id': 7, 'name': 'Pendant Lights'}, {'id': 8, 'name': 'Pull Down Faucet'}, {'id': 9, 'name': 'Tea Kettle'}, {'id': 10, 'name': 'Wall Mount Range Hood'}, {'id': 11, 'name': 'Wall Oven'}]
# Bar Stools
# Built-in Dishwasher
# Electric Or Gas Range
# French Door Refrigerator
# Knife Set
# Over the Range Microwave
# Pendant Lights
# Pull Down Faucet
# Tea Kettle
# Wall Mount Range Hood
# Wall Oven
# outdoor [{'id': 1, 'name': 'Market Umbrella'}, {'id': 2, 'name': 'Outdoor Bench'}, {'id': 3, 'name': 'Outdoor Chaise Lounge'}, {'id': 4, 'name': 'Outdoor Coffee Table'}, {'id': 5, 'name': 'Outdoor Dining Chair'}, {'id': 6, 'name': 'Outdoor Lounge Chair'}, {'id': 7, 'name': 'Outdoor Pillow'}, {'id': 8, 'name': 'Outdoor Rug'}, {'id': 9, 'name': 'Outdoor Side Table'}, {'id': 10, 'name': 'Outdoor Sofa'}, {'id': 11, 'name': 'Patio Dining Table'}, {'id': 12, 'name': 'Planter'}]
# Market Umbrella
# Outdoor Bench
# Outdoor Chaise Lounge
# Outdoor Coffee Table
# Outdoor Dining Chair
# Outdoor Lounge Chair
# Outdoor Pillow
# Outdoor Rug
# Outdoor Side Table
# Outdoor Sofa
# Patio Dining Table
# Planter
# livingroom [{'id': 1, 'name': 'Accent Chairs'}, {'id': 2, 'name': 'Area Rugs'}, {'id': 3, 'name': 'Coffee Tables'}, {'id': 4, 'name': 'Console Tables'}, {'id': 5, 'name': 'End Tables'}, {'id': 6, 'name': 'Floor Lamps'}, {'id': 7, 'name': 'Ottomans'}, {'id': 8, 'name': 'Sofas and Loveseats'}, {'id': 9, 'name': 'Table Lamps'}, {'id': 10, 'name': 'Throw Pillows'}, {'id': 11, 'name': 'Vases'}]
# Accent Chairs
# Area Rugs
# Coffee Tables
# Console Tables
# End Tables
# Floor Lamps
# Ottomans
# Sofas and Loveseats
# Table Lamps
# Throw Pillows
# Vases
# bedroom [{'id': 1, 'name': 'Accent Chairs'}, {'id': 2, 'name': 'Bedroom Benches'}, {'id': 3, 'name': 'Beds and Headboards'}, {'id': 4, 'name': 'Bookcases'}, {'id': 5, 'name': 'Dressers and Chests'}, {'id': 6, 'name': 'Flush Mount Lights'}, {'id': 7, 'name': 'Nightstands'}, {'id': 8, 'name': 'Ottomans'}, {'id': 9, 'name': 'Table Lamps'}, {'id': 10, 'name': 'Throw Pillows'}, {'id': 11, 'name': 'Wall Mirrors'}]
# Accent Chairs
# Bedroom Benches
# Beds and Headboards
# Bookcases
# Dressers and Chests
# Flush Mount Lights
# Nightstands
# Ottomans
# Table Lamps
# Throw Pillows
# Wall Mirrors

# %%
for k, v in inverse_model_dict.items():
    print(k, "|", v)
# Out:
# Bath Rugs and Mats | bathroom
# Centerset Bathroom Sink Faucets | bathroom
# Sconces | bathroom
# Showerheads | bathroom
# Single Handle Bathroom Sink Faucets | bathroom
# Toilet Bowls | bathroom
# Vanities with Tops | bathroom
# Vanity Mirrors | bathroom
# Widespread Bathroom Sink Faucets | bathroom
# Accent Chairs | bedroom
# Bookcases | bedroom
# Chandeliers | diningroom
# Dining Chairs | diningroom
# Kitchen and Dining Tables | diningroom
# Pendant Lights | kitchen
# Sideboards and Buffets | diningroom
# Vases | livingroom
# Bar Stools | kitchen
# Built-in Dishwasher | kitchen
# Electric Or Gas Range | kitchen
# French Door Refrigerator | kitchen
# Knife Set | kitchen
# Over the Range Microwave | kitchen
# Pull Down Faucet | kitchen
# Tea Kettle | kitchen
# Wall Mount Range Hood | kitchen
# Wall Oven | kitchen
# Market Umbrella | outdoor
# Outdoor Bench | outdoor
# Outdoor Chaise Lounge | outdoor
# Outdoor Coffee Table | outdoor
# Outdoor Dining Chair | outdoor
# Outdoor Lounge Chair | outdoor
# Outdoor Pillow | outdoor
# Outdoor Rug | outdoor
# Outdoor Side Table | outdoor
# Outdoor Sofa | outdoor
# Patio Dining Table | outdoor
# Planter | outdoor
# Area Rugs | livingroom
# Coffee Tables | livingroom
# Console Tables | livingroom
# End Tables | livingroom
# Floor Lamps | livingroom
# Ottomans | bedroom
# Sofas and Loveseats | livingroom
# Table Lamps | bedroom
# Throw Pillows | bedroom
# Bedroom Benches | bedroom
# Beds and Headboards | bedroom
# Dressers and Chests | bedroom
# Flush Mount Lights | bedroom
# Nightstands | bedroom
# Wall Mirrors | bedroom

# %%
checked = 0
covered_taxonomies = {}
for i, tax in enumerate(input_csv.taxonomy.unique()):
    total_classes = 0
    for c, od_m in inverse_model_dict.items():
        total_classes += 1
        if c.lower() in tax.lower():
            checked+=1
            covered_taxonomies[tax] = {'od_label':c,'model_name':od_m}
            break
    if total_classes == 54:
        print(i,tax)
print(checked)
### these are taxonomies that need manual encoding...
# Out:
# 1 appliances>microwaves>over-the-range microwaves
# 18 furniture>kids & baby furniture>kids furniture>kids bedroom furniture>kids beds & headboards
# 21 furniture>kitchen & dining room furniture>kitchen & dining tables
# 22 furniture>kitchen & dining room furniture>sideboards & buffets
# 28 furniture>living room furniture>sofas
# 30 home decor>mirrors>wall mirrors
# 62

# %%
### manual encode the special taxnomies...
covered_taxonomies['furniture>living room furniture>sofas'] = {'od_label':'Sofas and Loveseats','model_name':'livingroom'}
covered_taxonomies['furniture>bedroom furniture>dressers & chests'] = {'od_label':'Dressers and Chests','model_name':'bedroom'}
covered_taxonomies['appliances>microwaves>over-the-range microwaves'] ={'od_label':'Over the Range Microwave','model_name':'kitchen'}
covered_taxonomies['furniture>living room furniture>sofas & loveseats'] = {'od_label':'Sofas and Loveseats','model_name':'livingroom'}
covered_taxonomies['furniture>kitchen & dining room furniture>sideboards & buffets'] = {'od_label':'Sideboards and Buffets','model_name':'diningroom'}
covered_taxonomies['furniture>kitchen & dining room furniture>kitchen & dining tables'] = {'od_label':'Kitchen and Dining Tables','model_name':'diningroom'}
covered_taxonomies['furniture>kids & baby furniture>kids furniture>kids bedroom furniture>kids beds & headboards'] = {'od_label':'Beds and Headboards','model_name':'bedroom'}

# %%
covered_taxonomies['home decor>mirrors>wall mirrors']
# Out:
# {'od_label': 'Wall Mirrors', 'model_name': 'bedroom'}

# %%
def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    im_array = np.array(image.getdata())
    num_channels = im_array.shape[1]
    return im_array.reshape((im_height, im_width, num_channels)).astype(np.uint8)

# %%
client=bigquery.Client(project='analytics-online-data-sci-thd')

# %%
query = """
with popular_goods as (SELECT * EXCEPT(SCORE)
FROM
(
  SELECT
    P.OMS_ID ,
    CLASS,
    SUBCLASS,
    TAXONOMY ,
    SCORE,
    ROW_NUMBER() OVER(PARTITION BY CLASS ORDER BY SCORE DESC) AS ROW_NBR 
  FROM
    (
      SELECT DISTINCT
        OMS.OMS_ID , P.CLASS, P.SUBCLASS  , P.TAXONOMY 
      FROM
        `pr-edw-views-thd.NURO.PRODUCT` P
      INNER JOIN
        `pr-edw-views-thd.NURO.SKU_UPC_BY_OMS` OMS
      ON 
        P.OMS_ID = OMS.OMS_ID
        AND P.SKU_NBR = OMS.SKU_NBR 
        AND P.SKU_CRT_DT = OMS.SKU_CRT_DT 
        AND P.UPC_CD = OMS.UPC_CD 
      ) P
  INNER JOIN
    `analytics-online-thd.Master.top_seller_score` TS
  ON
    P.OMS_ID = TS.OMS_ID
)
WHERE ROW_NBR <= 1000), --top 1k SKUs from each Class BASED ON TOP SELLER SCORE)

mart_taxonomy as (
  select oms_sku omsid, array_reverse(split(taxonomy, ">"))[safe_offset(0)] as leafnode, * except(oms_sku)
  from `mart.lookup_product_taxonomy` 
),
taxonomy_stacked as (
  select omsid, taxonomy, l1 as l_n, leafnode
  from mart_taxonomy
  union all
  select omsid, taxonomy, l2 as l_n, leafnode
  from mart_taxonomy
  union all
  select omsid, taxonomy, l3 as l_n, leafnode
  from mart_taxonomy
  union all
  select omsid, taxonomy, l4 as l_n, leafnode
  from mart_taxonomy
  union all
  select omsid, taxonomy, l5 as l_n, leafnode
  from mart_taxonomy
  union all
  select omsid, taxonomy, l6 as l_n, leafnode
  from mart_taxonomy
)  ,
taxonomy_od_labels_mapping as(
select distinct *
from taxonomy_stacked 
where l_n in ('bath rugs and mats', 'centerset bathroom sink faucets', 'sconces', 'showerheads', 'single handle bathroom sink faucets', 'toilet bowls', 'vanities with tops', 'vanity mirrors', 'widespread bathroom sink faucets', 'accent chairs', 'bookcases', 'chandeliers', 'dining chairs', 'kitchen and dining tables', 'pendant lights', 'sideboards and buffets', 'vases', 'bar stools', 'built-in dishwasher', 'electric or gas range', 'french door refrigerator', 'knife set', 'over the range microwave', 'pull down faucet', 'tea kettle', 'wall mount range hood', 'wall oven', 'market umbrella', 'outdoor bench', 'outdoor chaise lounge', 'outdoor coffee table', 'outdoor dining chair', 'outdoor lounge chair', 'outdoor pillow', 'outdoor rug', 'outdoor side table', 'outdoor sofa', 'patio dining table', 'planter', 'area rugs', 'coffee tables', 'console tables', 'end tables', 'floor lamps', 'ottomans', 'sofas and loveseats', 'table lamps', 'throw pillows', 'bedroom benches', 'beds and headboards', 'dressers and chests', 'flush mount lights', 'nightstands', 'wall mirrors',
'starting from here are corrected categories',
'wall ovens',
'wall mount range hoods',
'bathroom vanities with tops',
'tea kettles',
'sofas & loveseats',
'sideboards & buffets',
'pull down faucets',
'planters',
'patio dining tables',
'over-the-range microwaves',
'sofas',
'outdoor side tables',
'outdoor rugs',
'outdoor pillows',
'outdoor lounge chairs',
'outdoor dining chairs',
'outdoor coffee tables',
'outdoor chaise lounges',
'outdoor benches',
'market umbrellas',
'knife sets',
'kitchen & dining tables',
'french door refrigerators',
'gas range',
'dressers & chests',
'built-in dishwashers',
'kids beds & headboards')),

sampled_skus_of_selected_taxonomies as (
select * from (select ROW_NUMBER() OVER(PARTITION BY taxonomy) AS row_num, *  from taxonomy_od_labels_mapping tm ) 
)--where row_num <= 400) -- limiting to 400 samples per taxonomy

select distinct sampled_skus_of_selected_taxonomies.omsid, sampled_skus_of_selected_taxonomies.taxonomy, l_n od_label, itc.image_url  
from sampled_skus_of_selected_taxonomies join `mart.itc_weekly_results` itc on sampled_skus_of_selected_taxonomies.omsid   = safe_cast(itc.oms_id as string)
where itc.prediction_labels like "%lifestyle%" and taxonomy  is not null 
AND sampled_skus_of_selected_taxonomies.omsid in (select distinct safe_cast(OMS_ID as string) from popular_goods)
order by taxonomy
"""

# %%
input_csv = client.query(query).to_dataframe()

# %%
input_csv
# Out:
#            omsid                                           taxonomy  \
# 0      304009661        appliances>dishwashers>built-in dishwashers
# 1      311179089        appliances>dishwashers>built-in dishwashers
# 2      306056770        appliances>dishwashers>built-in dishwashers
# 3      313572055        appliances>dishwashers>built-in dishwashers
# 4      306192068        appliances>dishwashers>built-in dishwashers
# 5      306183907        appliances>dishwashers>built-in dishwashers
# 6      310504268        appliances>dishwashers>built-in dishwashers
# 7      310600624        appliances>dishwashers>built-in dishwashers
# 8      206355384        appliances>dishwashers>built-in dishwashers
# 9      306184391        appliances>dishwashers>built-in dishwashers
# 10     306598179        appliances>dishwashers>built-in dishwashers
# 11     312291562        appliances>dishwashers>built-in dishwashers
# 12     310504269        appliances>dishwashers>built-in dishwashers
# 13     308823852        appliances>dishwashers>built-in dishwashers
# 14     306183414        appliances>dishwashers>built-in dishwashers
# 15     308580997        appliances>dishwashers>built-in dishwashers
# 16     206355369        appliances>dishwashers>built-in dishwashers
# 17     206355368        appliances>dishwashers>built-in dishwashers
# 18     313574576        appliances>dishwashers>built-in dishwashers
# 19     303415049        appliances>dishwashers>built-in dishwashers
# 20     301706264        appliances>dishwashers>built-in dishwashers
# 21     312284125        appliances>dishwashers>built-in dishwashers
# 22     310504270        appliances>dishwashers>built-in dishwashers
# 23     312283904        appliances>dishwashers>built-in dishwashers
# 24     300016780        appliances>dishwashers>built-in dishwashers
# 25     310600545        appliances>dishwashers>built-in dishwashers
# 26     301698069        appliances>dishwashers>built-in dishwashers
# 27     310504244        appliances>dishwashers>built-in dishwashers
# 28     310697377        appliances>dishwashers>built-in dishwashers
# 29     309281247        appliances>dishwashers>built-in dishwashers
# ...          ...                                                ...
# 14167  306923157  outdoors>patio furniture>patio umbrellas>marke...
# 14168  306923145  outdoors>patio furniture>patio umbrellas>marke...
# 14169  309389800  outdoors>patio furniture>patio umbrellas>marke...
# 14170  309390355  outdoors>patio furniture>patio umbrellas>marke...
# 14171  306923154  outdoors>patio furniture>patio umbrellas>marke...
# 14172  306923154  outdoors>patio furniture>patio umbrellas>marke...
# 14173  305663139  outdoors>patio furniture>patio umbrellas>marke...
# 14174  306923166  outdoors>patio furniture>patio umbrellas>marke...
# 14175  305185975  outdoors>patio furniture>patio umbrellas>marke...
# 14176  306923164  outdoors>patio furniture>patio umbrellas>marke...
# 14177  305663139  outdoors>patio furniture>patio umbrellas>marke...
# 14178  306923160  outdoors>patio furniture>patio umbrellas>marke...
# 14179  309304530  outdoors>patio furniture>patio umbrellas>marke...
# 14180  306923160  outdoors>patio furniture>patio umbrellas>marke...
# 14181  306923157  outdoors>patio furniture>patio umbrellas>marke...
# 14182  305185975  outdoors>patio furniture>patio umbrellas>marke...
# 14183  309304530  outdoors>patio furniture>patio umbrellas>marke...
# 14184  306923154  outdoors>patio furniture>patio umbrellas>marke...
# 14185  310515916  outdoors>patio furniture>patio umbrellas>marke...
# 14186  305663139  outdoors>patio furniture>patio umbrellas>marke...
# 14187  303618035         tools>hand tools>hand tool sets>knife sets
# 14188  303618035         tools>hand tools>hand tool sets>knife sets
# 14189  303618035         tools>hand tools>hand tool sets>knife sets
# 14190  205935391         tools>hand tools>hand tool sets>knife sets
# 14191  205754832         tools>hand tools>hand tool sets>knife sets
# 14192  205935391         tools>hand tools>hand tool sets>knife sets
# 14193  205935391         tools>hand tools>hand tool sets>knife sets
# 14194  303618035         tools>hand tools>hand tool sets>knife sets
# 14195  303618035         tools>hand tools>hand tool sets>knife sets
# 14196  205935391         tools>hand tools>hand tool sets>knife sets
#
#                    od_label                                          image_url
# 0      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 1      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 2      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 3      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 4      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 5      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 6      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 7      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 8      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 9      built-in dishwashers  https://images.homedepot-static.com/productIma...
# 10     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 11     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 12     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 13     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 14     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 15     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 16     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 17     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 18     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 19     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 20     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 21     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 22     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 23     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 24     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 25     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 26     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 27     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 28     built-in dishwashers  https://images.homedepot-static.com/productIma...
# 29     built-in dishwashers  https://images.homedepot-static.com/productIma...
# ...                     ...                                                ...
# 14167      market umbrellas  https://images.homedepot-static.com/productIma...
# 14168      market umbrellas  https://images.homedepot-static.com/productIma...
# 14169      market umbrellas  https://images.homedepot-static.com/productIma...
# 14170      market umbrellas  https://images.homedepot-static.com/productIma...
# 14171      market umbrellas  https://images.homedepot-static.com/productIma...
# 14172      market umbrellas  https://images.homedepot-static.com/productIma...
# 14173      market umbrellas  https://images.homedepot-static.com/productIma...
# 14174      market umbrellas  https://images.homedepot-static.com/productIma...
# 14175      market umbrellas  https://images.homedepot-static.com/productIma...
# 14176      market umbrellas  https://images.homedepot-static.com/productIma...
# 14177      market umbrellas  https://images.homedepot-static.com/productIma...
# 14178      market umbrellas  https://images.homedepot-static.com/productIma...
# 14179      market umbrellas  https://images.homedepot-static.com/productIma...
# 14180      market umbrellas  https://images.homedepot-static.com/productIma...
# 14181      market umbrellas  https://images.homedepot-static.com/productIma...
# 14182      market umbrellas  https://images.homedepot-static.com/productIma...
# 14183      market umbrellas  https://images.homedepot-static.com/productIma...
# 14184      market umbrellas  https://images.homedepot-static.com/productIma...
# 14185      market umbrellas  https://images.homedepot-static.com/productIma...
# 14186      market umbrellas  https://images.homedepot-static.com/productIma...
# 14187            knife sets  https://images.homedepot-static.com/productIma...
# 14188            knife sets  https://images.homedepot-static.com/productIma...
# 14189            knife sets  https://images.homedepot-static.com/productIma...
# 14190            knife sets  https://images.homedepot-static.com/productIma...
# 14191            knife sets  https://images.homedepot-static.com/productIma...
# 14192            knife sets  https://images.homedepot-static.com/productIma...
# 14193            knife sets  https://images.homedepot-static.com/productIma...
# 14194            knife sets  https://images.homedepot-static.com/productIma...
# 14195            knife sets  https://images.homedepot-static.com/productIma...
# 14196            knife sets  https://images.homedepot-static.com/productIma...
#
# [14197 rows x 4 columns]

# %%
for tax in input_csv.taxonomy.unique():
    if tax in covered_taxonomies.keys():
        continue
    else:
        print(tax)

# %%
input_csv.taxonomy.unique()
# Out:
# array(['appliances>dishwashers>built-in dishwashers',
#        'appliances>microwaves>over-the-range microwaves',
#        'appliances>range hoods>wall mount range hoods',
#        'appliances>refrigerators>french door refrigerators',
#        'appliances>wall ovens>electric wall ovens>double electric wall ovens',
#        'appliances>wall ovens>electric wall ovens>single electric wall ovens',
#        'appliances>wall ovens>gas wall ovens>single gas wall ovens',
#        'appliances>wall ovens>wall oven & microwave combinations',
#        'appliances>wall ovens>warming drawers',
#        'bath>bathroom faucets>bathroom sink faucets>centerset bathroom sink faucets',
#        'bath>bathroom faucets>bathroom sink faucets>single handle bathroom sink faucets',
#        'bath>bathroom faucets>bathroom sink faucets>widespread bathroom sink faucets',
#        'bath>bathroom faucets>showerheads>fixed showerheads',
#        'bath>bathroom faucets>showerheads>handheld showerheads',
#        'bath>bathroom mirrors>vanity mirrors',
#        'bath>bathroom vanities>bathroom vanities with tops',
#        'bath>toilets, toilet seats & bidets>toilet bowls',
#        'bath>toilets>toilet bowls', 'flooring>rugs>area rugs',
#        'flooring>rugs>outdoor rugs',
#        'furniture>bedroom furniture>dressers & chests',
#        'furniture>bedroom furniture>nightstands',
#        'furniture>home office furniture>bookcases',
#        'furniture>kids & baby furniture>kids furniture>kids bedroom furniture>kids beds & headboards',
#        'furniture>kitchen & dining room furniture>bar stools',
#        'furniture>kitchen & dining room furniture>dining chairs',
#        'furniture>kitchen & dining room furniture>kitchen & dining tables',
#        'furniture>kitchen & dining room furniture>sideboards & buffets',
#        'furniture>living room furniture>accent tables>coffee tables',
#        'furniture>living room furniture>accent tables>console tables',
#        'furniture>living room furniture>accent tables>end tables',
#        'furniture>living room furniture>chairs>accent chairs',
#        'furniture>living room furniture>ottomans',
#        'furniture>living room furniture>sofas',
#        'furniture>living room furniture>sofas & loveseats',
#        'home decor>home accents>vases', 'home decor>mirrors>wall mirrors',
#        'home decor>throw pillows',
#        'kitchen>kitchen faucets>pull down faucets',
#        'kitchen>kitchenware>cookware>tea kettles',
#        'kitchen>kitchenware>cutlery>knife sets', 'lighting>chandeliers',
#        'lighting>flush mount lights', 'lighting>lamps>floor lamps',
#        'lighting>lamps>table lamps', 'lighting>pendant lights',
#        'lighting>sconces',
#        'outdoors>garden center>planters>barrel planters',
#        'outdoors>garden center>planters>glass terrariums',
#        'outdoors>garden center>planters>grow bags',
#        'outdoors>garden center>planters>hanging baskets',
#        'outdoors>garden center>planters>hanging planters',
#        'outdoors>garden center>planters>plant hangers',
#        'outdoors>garden center>planters>plant liners',
#        'outdoors>garden center>planters>plant pots',
#        'outdoors>garden center>planters>plant stands',
#        'outdoors>garden center>planters>planter accessories',
#        'outdoors>garden center>planters>planter accessories>miscellaneous planter accessories',
#        'outdoors>garden center>planters>planter boxes',
#        'outdoors>garden center>planters>planter caddies',
#        'outdoors>garden center>planters>planter saucers',
#        'outdoors>garden center>planters>potting benches and tables',
#        'outdoors>garden center>planters>railing planters',
#        "outdoors>garden center>planters>shepherd's hooks",
#        'outdoors>garden center>planters>urn planters',
#        'outdoors>garden center>planters>vertical garden planters',
#        'outdoors>garden center>planters>wall planters',
#        'outdoors>garden center>planters>window boxes',
#        'outdoors>patio furniture>outdoor pillows>outdoor lumbar pillows',
#        'outdoors>patio furniture>outdoor pillows>outdoor throw pillows',
#        'outdoors>patio furniture>patio accessories>outdoor pillows',
#        'outdoors>patio furniture>patio accessories>outdoor pillows>outdoor bolster pillows',
#        'outdoors>patio furniture>patio accessories>outdoor pillows>outdoor lumbar pillows',
#        'outdoors>patio furniture>patio accessories>outdoor pillows>outdoor throw pillows',
#        'outdoors>patio furniture>patio chairs>outdoor benches',
#        'outdoors>patio furniture>patio chairs>outdoor chaise lounges',
#        'outdoors>patio furniture>patio chairs>outdoor dining chairs',
#        'outdoors>patio furniture>patio chairs>outdoor lounge chairs',
#        'outdoors>patio furniture>patio tables>outdoor coffee tables',
#        'outdoors>patio furniture>patio tables>outdoor side tables',
#        'outdoors>patio furniture>patio tables>patio dining tables',
#        'outdoors>patio furniture>patio umbrellas>market umbrellas',
#        'tools>hand tools>hand tool sets>knife sets'], dtype=object)

# %%
def determine_final_coords(cropped_coords,original_dims,cropped_dims,aspect_ratio = 1, expansion_factor = 0.05):
    w_cropped, h_cropped = cropped_dims
    w, h = original_dims
    w_diff, h_diff = (w-w_cropped)/2.0,(h-h_cropped)/2.0
    left_boud = w_diff
    right_bound = w - w_diff
    top_bound = h_diff
    bottom_bound = h-h_diff
    ## compute shortest dist to original boundaries...
    h_top,w_left,h_bottom,w_right = cropped_coords ## in percentiles...
    w_boundbox = w_right-w_left
    h_boundbox = h_bottom-h_top  ## in percentiles...
    h_center,w_center = (h_top+h_bottom)/2.0, (w_left+w_right)/2.0
    #print("h_top,w_left,h_bottom,w_right",h_top,w_left,h_bottom,w_right)
    if w_boundbox > h_boundbox:
        longer_edge = w_boundbox*w
        new_width = min(int(longer_edge*(1+expansion_factor)),w_cropped)
        new_height = min(int(new_width/aspect_ratio),h_cropped)
        if new_width > new_height*aspect_ratio:
            new_width = new_height*aspect_ratio
        u,b = int(h_top*h), int(h_bottom*h)
        l,r = int(w_left*w),int(w_right*w)
        #l,r = min(int(w_center*w - new_width/2.0),left_boud),max(int(w_center*w + new_width/2.0),right_bound)
        while True:
            if l > left_boud:
                l -= 1
            if r - l >= new_width:
                break
            if r < right_bound and r > 0:
                r += 1
            if r - l >= new_width:
                break  
        while True:
            if u > top_bound:
                u -= 1
            if b - u >= new_height:
                break
            if b < bottom_bound and b > 0:
                b += 1
            if b - u >= new_height:
                break
    else:
        longer_edge = h_boundbox*h
        new_height = min(int(longer_edge*(1+expansion_factor)),h_cropped)
        new_width = min(int(new_height*aspect_ratio),w_cropped)
        if new_width < new_height*aspect_ratio:
            new_height = new_width/aspect_ratio
        #u,b = min(int(h_center*h - new_height/2.0),top_bound), max(int(h_center*h + new_height/2.0),bottom_bound)
        l,r = int(w_left*w),int(w_right*w)
        u,b = int(h_top*h), int(h_bottom*h)
        #print(new_edge_length,"new edge length")
        while True:
            if l > left_boud:
                l -= 1
            if r - l >= new_width:
                break
            if r < right_bound and r > 0:
                r += 1
            if r - l >= new_width:
                break 
        while True:
            if u > top_bound:
                u -= 1
            if b - u >= new_height:
                break
            if b < bottom_bound and b > 0:
                b += 1
            if b - u >= new_height:
                break  
    #print("u,l,b,r","|",u,l,b,r)
    ## final check if aspect-ratio is satisfied...
    if aspect_ratio*(b - u) < r - l:
        horiz_center = (l+r)/2.0
        r = int(horiz_center+aspect_ratio*(b - u)/2.0)
        l = int(horiz_center-aspect_ratio*(b - u)/2.0)
    if aspect_ratio*(b - u) > r - l:
        verti_center = (b+u)/2.0
        b = int(verti_center+(r-l)/(aspect_ratio*2.0))
        u = int(verti_center-(r-l)/(aspect_ratio*2.0))
    swapped_cropp_coords = (l,u,r,b)
    return swapped_cropp_coords

# %%
def cropping_out_white_boarder(image_np):
    ## (1) Convert to gray, and threshold
    gray = cv2.cvtColor(image_np, cv2.COLOR_BGR2GRAY)
    th, threshed = cv2.threshold(gray, 220, 255, cv2.THRESH_BINARY_INV)
    ## (2) Morph-op to remove noise
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11,11))
    morphed = cv2.morphologyEx(threshed, cv2.MORPH_CLOSE, kernel)
    ## (3) Find the max-area contour
    cnts = cv2.findContours(morphed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[-2]
    cnt = sorted(cnts, key=cv2.contourArea)[-1]
    ## (4) Crop and save it
    x,y,w,h = cv2.boundingRect(cnt)
    dst = image_np[y:y+h, x:x+w]
    return dst

# %%
input_csv.columns
# Out:
# Index(['omsid', 'taxonomy', 'od_label', 'image_url'], dtype='object')

# %%
nbr_cropped = 0
results_path = './results/nov-12-outputs/'
for j, row in input_csv.iterrows():
    img_pth,taxonomy,image_name = row.image_url,row.taxonomy,row.image_url.split("/")[4]
    if taxonomy == 'appliances>dishwashers>built-in dishwashers':
        continue
    if type(taxonomy) == str and taxonomy in covered_taxonomies.keys():
        resp = urllib.request.urlopen(img_pth)
        image = np.asarray(bytearray(resp.read()), dtype="uint8")
        image_np = cv2.imdecode(image, cv2.IMREAD_COLOR)
        image_np = cv2.cvtColor(image_np, cv2.COLOR_RGB2BGR)
        image_np_no_white_boarder = cropping_out_white_boarder(image_np)
        w_cropped, h_cropped = image_np_no_white_boarder.shape[1],image_np_no_white_boarder.shape[0]
        detection_graph = model_dict[covered_taxonomies[taxonomy]['model_name']]['detection_graph']
        target_OD_result = covered_taxonomies[taxonomy]['od_label']
        categories = model_dict[covered_taxonomies[taxonomy]['model_name']]['categories']
        print(j,"| Using the",covered_taxonomies[taxonomy]['model_name'],"model | target label:",target_OD_result)
        with detection_graph.as_default():
            with tf.Session(graph=detection_graph) as sess:
                image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
                detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
                detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
                detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
                num_detections = detection_graph.get_tensor_by_name('num_detections:0')
                (boxes, scores, classes, num) = sess.run(
                [detection_boxes, detection_scores, detection_classes, num_detections],
                feed_dict={image_tensor: np.expand_dims(image_np, axis=0)})
                for i,score in enumerate(np.squeeze(scores)[6::-1]):
                    if np.squeeze(scores)[i] >= 0.6 and categories[np.squeeze(classes)[i].astype(int)-1]['name'] == target_OD_result:
                        nbr_cropped += 1
                        print(j,"image_cropped | Total:", nbr_cropped)
                        for asp in [1.0,1.77]:
                            final_coords = determine_final_coords(boxes[0,i],(image_np.shape[0],image_np.shape[1]),(w_cropped, h_cropped),aspect_ratio=asp, expansion_factor = 1.0)
                            img = Image.fromarray(image_np).crop(final_coords)
                            create_dir_if_needed(results_path+target_OD_result+"/"+str(image_name)+'.jpg')
                            fname = str(row.omsid)+'|'+str(image_name)+'|'+covered_taxonomies[taxonomy]['model_name']+'|'+target_OD_result+'|'+str(asp)+'.jpg'
                            img.save(results_path+target_OD_result+"/"+fname, quality=100)
# Out:
# 924 | Using the kitchen model | target label: Over the Range Microwave
# 924 image_cropped | Total: 1
# 925 | Using the kitchen model | target label: Over the Range Microwave
# 925 image_cropped | Total: 2
# 926 | Using the kitchen model | target label: Over the Range Microwave
# 927 | Using the kitchen model | target label: Over the Range Microwave
# 928 | Using the kitchen model | target label: Over the Range Microwave
# 928 image_cropped | Total: 3
# 929 | Using the kitchen model | target label: Over the Range Microwave
# 930 | Using the kitchen model | target label: Over the Range Microwave
# 930 image_cropped | Total: 4
# 931 | Using the kitchen model | target label: Over the Range Microwave
# 932 | Using the kitchen model | target label: Over the Range Microwave
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-028bdb4aed8a> in <module>
#      25                 (boxes, scores, classes, num) = sess.run(
#      26                 [detection_boxes, detection_scores, detection_classes, num_detections],
# ---> 27                 feed_dict={image_tensor: np.expand_dims(image_np, axis=0)})
#      28                 for i,score in enumerate(np.squeeze(scores)[6::-1]):
#      29                     if np.squeeze(scores)[i] >= 0.6 and categories[np.squeeze(classes)[i].astype(int)-1]['name'] == target_OD_result:
#
# /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
taxonomy
# Out:
# 'appliances>microwaves>over-the-range microwaves'

# %%
### test....
nbr_cropped = 0
results_path = './results/nov-12-outputs/'
for j, row in input_csv.iterrows():
    if str(row.OMS_ID) == '100075906':
        print(row.image_url,row.TAXONOMY,row.image_url.split("/")[4])
        img_pth,taxonomy,image_name = row.image_url,row.TAXONOMY,row.image_url.split("/")[4]
        if type(taxonomy) == str and taxonomy in covered_taxonomies.keys():
            resp = urllib.request.urlopen(img_pth)
            image = np.asarray(bytearray(resp.read()), dtype="uint8")
            image_np = cv2.imdecode(image, cv2.IMREAD_COLOR)
            image_np = cv2.cvtColor(image_np, cv2.COLOR_RGB2BGR)
            image_np_no_white_boarder = cropping_out_white_boarder(image_np)
            w_cropped, h_cropped = image_np_no_white_boarder.shape[1],image_np_no_white_boarder.shape[0]
            detection_graph = model_dict[covered_taxonomies[taxonomy]['model_name']]['detection_graph']
            target_OD_result = covered_taxonomies[taxonomy]['od_label']
            categories = model_dict[covered_taxonomies[taxonomy]['model_name']]['categories']
            print(j,"| Using the",covered_taxonomies[taxonomy]['model_name'],"model | target label:",target_OD_result)
            with detection_graph.as_default():
                with tf.Session(graph=detection_graph) as sess:
                    image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
                    detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
                    detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
                    detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
                    num_detections = detection_graph.get_tensor_by_name('num_detections:0')
                    (boxes, scores, classes, num) = sess.run(
                    [detection_boxes, detection_scores, detection_classes, num_detections],
                    feed_dict={image_tensor: np.expand_dims(image_np, axis=0)})
                    for i,score in enumerate(np.squeeze(scores)[6::-1]):
                        if np.squeeze(scores)[i] >= 0.6 and categories[np.squeeze(classes)[i].astype(int)-1]['name'] == target_OD_result:
                            nbr_cropped += 1
                            print(j,"image_cropped | Total:", nbr_cropped, np.squeeze(scores)[i])
                            for asp in [1.0,1.77]:
                                final_coords = determine_final_coords(boxes[0,i],(image_np.shape[0],image_np.shape[1]),(w_cropped, h_cropped),aspect_ratio=asp, expansion_factor = 1.0)
                                img = Image.fromarray(image_np).crop(final_coords)
                                create_dir_if_needed(results_path+"/"+str(i)+"/"+str(image_name)+'.jpg')
                                fname = str(row.OMS_ID)+'|'+str(image_name)+'|'+covered_taxonomies[taxonomy]['model_name']+'|'+target_OD_result+'|'+str(asp)+'.jpg'
                                img.save(results_path+target_OD_result+"/"+fname, quality=100)

# %%
for i,score in enumerate(np.squeeze(scores)[6::-1]):
    print(i, score,categories[np.squeeze(classes)[i].astype(int)-1]['name'])

# %%
my_results_dir = 'results/nov-12-outputs/'

# %%
for dp, dn, filenames in os.walk(my_results_dir):
    if "ipynb_checkpoints" not in dp and dp.split("/")[-1] != "":
        #print(dp.split("/")[-1],"|",inverse_model_dict[dp.split("/")[-1]])
        for filename in filenames:
            new_dir = 'results/nov-12-outputs-by-room/'+inverse_model_dict[dp.split("/")[-1]]+"/"+filename
            create_dir_if_needed(new_dir)
            shutil.copy(dp+"/"+filename,new_dir)

# %%
for dp, dn, filenames in os.walk('results/nov-12-outputs-by-room/'):
    print(dp)
# Out:
# results/nov-12-outputs-by-room/
# results/nov-12-outputs-by-room/outdoor
# results/nov-12-outputs-by-room/bedroom
# results/nov-12-outputs-by-room/diningroom
# results/nov-12-outputs-by-room/kitchen
# results/nov-12-outputs-by-room/livingroom
# results/nov-12-outputs-by-room/bathroom

# %%
def convert_folder_name(folder_name):
    ans = folder_name.replace("|","%7C")
    ans = ans.replace(" ","%20")
    return ans

# %%
i = 0
my_scripts = {}
for dp, dn, filenames in os.walk('results/nov-12-outputs-by-room'):
    if "ipynb_checkpoints" not in dp and dp.split("/")[-1] != "":
        my_scripts[dp.split("/")[-1]] = []
        for f in filenames:
            if f.split("|")[-1] == "1.0.jpg":
                full_image = "https://idm.homedepot.com/assets/image/"+f.split("|")[1][:2]+"/"+f.split("|")[1]+".jpg"
                img_asp_1 = "https://storage.cloud.google.com/ds_tianlong/cropping-image-results/"+dp.split("/")[1]+"/"+dp.split("/")[2]+"/"+f
                img_asp_177 = "https://storage.cloud.google.com/ds_tianlong/cropping-image-results/"+dp.split("/")[1]+"/"+dp.split("/")[2]+"/"+f.split(".")[0] + ".77.jpg"
                img_asp_1 = convert_folder_name(img_asp_1)
                img_asp_177 = convert_folder_name(img_asp_177)
                #print(full_image,Seg_img)
                curr_dict = {"Org_img":full_image,
                             "Seg_img":img_asp_1,
                             "edg_img":img_asp_177,
                             "feedback_objects":["cropping_size","cropping_quality"]}
                my_scripts[dp.split("/")[-1]].append(curr_dict)

# %%
my_scripts.keys()
# Out:
# dict_keys(['nov-12-outputs-by-room', 'outdoor', 'bedroom', 'diningroom', 'kitchen', 'livingroom', 'bathroom'])

# %%
subdirs = [x[0] for x in os.walk('results/nov-12-outputs-by-room')] 
for subdir in subdirs:
    if subdir.split("/")[-1] != "" and '.ipynb_checkpoints' not in subdir:
        subdir = subdir.split("/")[-1]
        with open ('orange-seed-scripts/'+subdir.replace(" ","_").lower()+".txt",'w+') as fp:
            fp.write(str(my_scripts[subdir]))
        fp.close()

# %%
## recursively find number of all files in current dir
find . -type f | wc -l
## move results to specific gcs folder.
gsutil -m cp -r nov-12-outputs-by-room/ gs://ds_tianlong/cropping-image-results/
